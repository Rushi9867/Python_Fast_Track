# %%
from flask import Flask,request,jsonify
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as urReq

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"iphone13"
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone13'

# %%
urReq(flipkart_url)

# %%
response_website = urReq(flipkart_url)
data_flipkart = response_website.read()

# %%
beautifyed_html = bs(data_flipkart,"html.parser")
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = beautifyed_html.find_all("div",{"class":"_1AtVbE col-12-12"})
bigbox[6].div.div.div.a['href']
# Out:
# '/apple-iphone-13-green-128-gb/p/itm18a55937b2607?pid=MOBGC9VGSU9DWGJZ&lid=LSTMOBGC9VGSU9DWGJZFWCDJN&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=9118f0fd-bbbf-4d58-b8da-0f3fe245deeb.MOBGC9VGSU9DWGJZ.SEARCH&ppt=None&ppn=None&ssid=851ukgrm280000001661772412224&qH=7d4afaedfc628b80'

# %%
product6 = "https://www.flipkart.com"+bigbox[6].div.div.div.a['href']
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-13-green-128-gb/p/itm18a55937b2607?pid=MOBGC9VGSU9DWGJZ&lid=LSTMOBGC9VGSU9DWGJZFWCDJN&marketplace=FLIPKART&q=iphone13&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=9118f0fd-bbbf-4d58-b8da-0f3fe245deeb.MOBGC9VGSU9DWGJZ.SEARCH&ppt=None&ppn=None&ssid=851ukgrm280000001661772412224&qH=7d4afaedfc628b80'

# %%
import requests
product66 = requests.get(product6)
product66
# Out:
# <Response [200]>

# %%
product66.encoding = 'utf-8'

# %%
product6_page = bs(product66.text,"html.parser")
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
all_review=product6_page.find_all("div",{"class":"_16PBlm"})
len(all_review)
# Out:
# 11

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">It's  just mind-blowing  I have switched from Android to iOS it feels fantastic. The  alluring effect and  the fascinated color it's top notch. I was hesitating to buy online but one can completely rely on. Special thanks to ekart and flipkart to deliver only in 2days delivery is quick  and trustworthy.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110_0d41d8b82ff14986ad79d8b8a5464714.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blo
# ...

# %%
rating = all_review[5].div.div.div.div.text
rating
# Out:
# '5'

# %%
name = all_review[5].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
name
# Out:
# 'ritu mishra'

# %%
all_review[5].div.div.div.find_all('p',{"class":"_2-N8zT"})[0].text
# Out:
# 'Terrific purchase'

# %%
header = all_review[5].div.div.div.p.text
header
# Out:
# 'Terrific purchase'

# %%
comment = all_review[5].div.div.find_all("div", {"class":""})[0].div.text
comment
# Out:
# "It's  just mind-blowing  I have switched from Android to iOS it feels fantastic. The  alluring effect and  the fascinated color it's top notch. I was hesitating to buy online but one can completely rely on. Special thanks to ekart and flipkart to deliver only in 2days delivery is quick  and trustworthy."

# %%
date = all_review[5].div.div.find_all("p",{"class":"_2sc7ZR"})[1].text
date
# Out:
# '10months ago'

# %%
price = product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text
price
# Out:
# '₹65,999'

# %%
for i in all_review:
    name = i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating = i.div.div.div.div.text
    header = i.div.div.div.p.text
    date = i.div.div.find_all("p",{"class":"_2sc7ZR"})[1].text
    comment = i.div.div.find_all("div", {"class":""})[0].div.text
    price = product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text
    print(name,rating,header,date,price,comment)
    print()
# Out:
# Mahim Chauhan 5 Brilliant 2months ago ₹65,999 I switch to ios from android after 10 years so this review might help for migratorsIt’s been a month using the iPhone13 and this was my experience1. Design - its simple and no nonsense design . Expect white and pink rest of the colours are fingerprint magnets.  I have seen all the colours and I highly recommend the pink . It’s so light pink which makes it not girlish. See it for yourself it really looks so premium in light pink colour. For rest of it except white the aluminium frame wil...
#
# ...
