# %%
#!pip3 install pandas-profiling

# %%
import pandas as pd 
import pandas_profiling
import numpy as np 
import seaborn as sns
import os

# %%
FitBit = pd.read_csv("FitBit data.csv")
FitBit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
#FitBit.profile_report()

# %%
FitBit.shape
# Out:
# (457, 15)

# %%
FitBit.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.000000                  0.020000
# 75%                    0.000000            1.310000                  0.670000
# max                    6.727057           21.920000                  6.400000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           457.000000               457.000000         457.000000
# mean              2.890197                 0.001904          16.623632
# std               2.237523                 0.008487          28.919704
# min               0.000000                 0.000000           0.000000
# 25%               0.870000                 0.000000           0.000000
# 50%               2.930000                 0.000000           0.000000
# 75%               4.460000                 0.000000          25.000000
# max              12.510000                 0.100000         202.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           457.000000            457.000000        457.000000
# mean             13.070022            170.070022        995.282276
# std              36.208635            122.205372        337.021404
# min               0.000000              0.000000         32.000000
# 25%               0.000000             64.000000        728.000000
# 50%               1.000000            181.000000       1057.000000
# 75%              16.000000            257.000000       1285.000000
# max             660.000000            720.000000       1440.000000
#
#           Calories
# count   457.000000
# mean   2189.452954
# std     815.484523
# min       0.000000
# 25%    1776.000000
# 50%    2062.000000
# 75%    2667.000000
# max    4562.000000

# %%
FitBit.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
FitBit.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
FitBit.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
FitBit['ActivityDate'].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
FitBit['Date'] = pd.DatetimeIndex(FitBit['ActivityDate'])

# %%
FitBit.dtypes
# Out:
# Id                                   int64
# ActivityDate                        object
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# Date                        datetime64[ns]
# dtype: object

# %%
FitBit['Day'] = pd.DatetimeIndex(FitBit['ActivityDate']).day
FitBit['Month'] = pd.DatetimeIndex(FitBit['ActivityDate']).month
FitBit['Year'] = pd.DatetimeIndex(FitBit['ActivityDate']).year
FitBit
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#           Date  Day  Month  Year
# 0   2016-03-25   25      3  2016
# 1   2016-03-26   26      3  2016
# 2   2016-03-27   27      3  2016
# 3   2016-03-28   28      3  2016
# 4   2016-03-29   29      3  2016
# ..         ...  ...    ...   ...
# 452 2016-04-08    8      4  2016
# 453 2016-04-09    9      4  2016
# 454 2016-04-10   10      4  2016
# 455 2016-04-11   11      4  2016
# 456 2016-04-12   12      4  2016
#
# [457 rows x 19 columns]

# %%
FitBit[['Date','Day','Month','Year']]
# Out:
#           Date  Day  Month  Year
# 0   2016-03-25   25      3  2016
# 1   2016-03-26   26      3  2016
# 2   2016-03-27   27      3  2016
# 3   2016-03-28   28      3  2016
# 4   2016-03-29   29      3  2016
# ..         ...  ...    ...   ...
# 452 2016-04-08    8      4  2016
# 453 2016-04-09    9      4  2016
# 454 2016-04-10   10      4  2016
# 455 2016-04-11   11      4  2016
# 456 2016-04-12   12      4  2016
#
# [457 rows x 4 columns]

# %%
FitBit.drop(['ActivityDate'],axis=1,inplace=True)

# %%
FitBit['Week'] = pd.DatetimeIndex(FitBit['Date']).week
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4536\831821933.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   FitBit['Week'] = pd.DatetimeIndex(FitBit['Date']).week

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.boxplot(x='Day',y='Calories',data=FitBit)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Calories'>

# %%
FitBit['Day_Name'] = FitBit['Date'].dt.day_name()
FitBit.head()
# Out:
#            Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366       11004           7.11             7.11
# 1  1503960366       17609          11.55            11.55
# 2  1503960366       12736           8.53             8.53
# 3  1503960366       13231           8.93             8.93
# 4  1503960366       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#         Date  Day  Month  Year  Week  Day_Name
# 0 2016-03-25   25      3  2016    12    Friday
# 1 2016-03-26   26      3  2016    12  Saturday
# 2 2016-03-27   27      3  2016    12    Sunday
# 3 2016-03-28   28      3  2016    13    Monday
# 4 2016-03-29   29      3  2016    13   Tuesday

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.boxplot(x='Day_Name',y='Calories',data=FitBit)
# Out:
# <AxesSubplot:xlabel='Day_Name', ylabel='Calories'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='Calories',y='TotalSteps',data=FitBit)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='TotalSteps'>

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot
ax = sns.scatterplot(x='Calories', y='SedentaryMinutes', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot
ax = sns.scatterplot(x='Calories', y='LightlyActiveMinutes', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt in the moderately active minutes
ax = sns.scatterplot(x='Calories', y='FairlyActiveMinutes', data=FitBit)

ax.set_title('Scatterplot of calories vs Fairly Active Minutes')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories vs Fairly Active Minutes')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt in the intensely active minutes
ax = sns.scatterplot(x='Calories', y='VeryActiveMinutes', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
FitBit=FitBit.drop(['Week','Year'],axis=1) # dropping the columns week and year

# %%
FitBit.head()
# Out:
#            Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366       11004           7.11             7.11
# 1  1503960366       17609          11.55            11.55
# 2  1503960366       12736           8.53             8.53
# 3  1503960366       13231           8.93             8.93
# 4  1503960366       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#         Date  Day  Month  Day_Name
# 0 2016-03-25   25      3    Friday
# 1 2016-03-26   26      3  Saturday
# 2 2016-03-27   27      3    Sunday
# 3 2016-03-28   28      3    Monday
# 4 2016-03-29   29      3   Tuesday

# %%
FitBit.shape
# Out:
# (457, 18)

# %%
## plot the raw values 

col_select = ['Calories','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']
wide_df = FitBit[col_select]

# figure size
plt.figure(figsize=(15,8))

# timeseries plot using lineplot
ax = sns.lineplot(data=wide_df)

ax.set_title('Un-normalized value of calories and different activities based on activity minutes')
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on activity minutes')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between  calories burnt and total distance covered
ax = sns.scatterplot(x='Calories', y='TotalDistance', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt and the loggged activities distance
ax = sns.scatterplot(x='Calories', y='LoggedActivitiesDistance', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt and the distance of intense activies
ax = sns.scatterplot(x='Calories', y='VeryActiveDistance', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot between calories burnt and the distance of moderate activities
ax = sns.scatterplot(x='Calories', y='ModeratelyActiveDistance', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
# figure size
plt.figure(figsize=(15,8))

# Simple scatterplot
ax = sns.scatterplot(x='Calories', y='LightActiveDistance', data=FitBit)

ax.set_title('Scatterplot of calories and intense_activities')
# Out:
# Text(0.5, 1.0, 'Scatterplot of calories and intense_activities')

# %%
## plot the raw values 

rol_select = ['TotalDistance','LoggedActivitiesDistance','VeryActiveDistance','ModeratelyActiveDistance', 'LightActiveDistance']
wide_df1 = FitBit[rol_select]

# figure size
plt.figure(figsize=(15,8))

# timeseries plot using lineplot
ax = sns.lineplot(data=wide_df1)

ax.set_title('Un-normalized value of calories and different activities based on distance')
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on distance')

# %% [markdown]
# The  EDA here gives us the insight about the relation between the active hours, the distance for which the user has moderate and intense activity and the calories burnt during that period.
